# %%
import codecs
import pandas
db = codecs.open("All_iPod_Music_Cleaned_Up_031114.txt", 'rU', 'UTF16')
db = pandas.read_csv(db, sep='\t') # which is a pandas data type, though it's a lot like a dict
db_dict = dict(db)
db_list = list(db)

# %%
db_dict['Artist'][1902]
alphabetized_artists = sorted(db_dict['Artist'])
alphabetized_artists[2]
# Out:
# '10,000 Maniacs'

# %%
# 1. Sum how many songs each artist has and make a dictionary

def getNumEntities(a):
    b = sorted(a)
    last = b[0]
    first = 0
    count = []
    field_name = []
    for i in xrange(1, len(b)):
        if a[i] == last:
            continue
        else:
            count.append(i - first)
            field_name.append(last)
            last = b[i]
            first = i
    return field_name, count

# %%
(unique_artists, counts) = getNumEntities(alphabetized_artists)
# now make a dictionary
artist_num_songs = dict(zip(unique_artists, counts))

# %%
artist_num_songs['Al Green']
# Out:
# 28

# %%
# It would be nicer instead to have all albums in a dictionary, e.g. a dictionary of dictionaries...
# to look like:
# artist_dict = {'name': 'The Beatles', 'albums':[{'name':'Please Please Me','year':1968, 'songs':{'}},{'name':
# 'Help!','year':1969}]}
from collections import defaultdict
songs = db['Name']
albums = db['Album']
artists = db['Artist']
playcounts = db['Plays']
skipcounts = db['Skips']
years = db['Year']
tracknum = db['Track Number']
tracktot = db['Track Count']
# artist_dict = dict.fromkeys(artists)
# artist_dict = defaultdict(dict) # automatically create a subdict
# artist_dict = {x:i for x,i in enumerate(artists)} # just puts integers in there for now

# %%
# An artist has albums, songs, and more
from numpy import *

# create Song class
class Song(object):
    '''song, an entity of album and artist'''
    def __init__(self, name, track_num, play_count, skip_count):
        self.name = name
        # self.album = album # the parent class
        # self.year -- don't include this because it will be part of the Album class
        self.track_num = track_num
        self.play_count = play_count
        self.skip_count = skip_count
        
# create Album parent class
class Album:
    def __init__(self, name, year, track_total, song):
        self.name = name
        self.year = year
        self.track_total = track_total
        self.song = song
    
    # return a list of the songs on the album. doesn't work.
    def __songs__(self):
        return self.song

# create the parent parent Artist class
class Artist:
    def __init__(self, name, album):
        self.name = name
        self.album = album

# %%
ar = [0] * len(artists)
for i in range(0, len(songs)):
    song = Song(songs[i], tracknum[i], playcounts[i], skipcounts[i])
    album = Album(albums[i], years[i], tracktot[i], song)
    ar[i] = Artist(artists[i], album)

ar[7].album.name
# Out:
# 'The Very Best Of Al Green'

# %%
# sort by album name
ar_sorted = sorted(ar, key=lambda artist: artist.album.name)

# %%
ar_sorted[7].album.name
# Out:
# nan

# %%
ar_sorted[0].album.song.name
len(ar_sorted)
# Out:
# 29866

# %%
al = [0] * len(albums)
for i in range(0, len(albums)):
    song = Song(songs[i], tracknum[i], playcounts[i], skipcounts[i])
    al[i] = Album(albums[i], years[i], tracktot[i], song)
    
al_sorted = sorted(al, key=lambda album: album.name)
al_sorted[0].name
isnan(al_sorted[0].name)
# Out:
# True

# %%
# 2. Determine the number of albums an artist has
ar_sorted2 = sorted(ar, key=lambda artist: artist.name)
album_dict = {}
last = ar_sorted2[0].name
albums_by_artist = ar_sorted2[0].album.name
for i in xrange(1, len(ar_sorted2)):
    if ar_sorted2[i].name == last:
        albums_by_artist.add(ar_sorted2[i].album.name) # since it's a set, it won't add duplicates
    else:
        # store in dictionary
        album_dict[last] = albums_by_artist
        # reset to empty set
        albums_by_artist = set()
        last = ar_sorted2[i].name

# %%
album_dict = dict(album_dict)

# %%
numAlbums = [0] * len(unique_artists)
album_artist_counts = {}
for i in xrange(0, len(unique_artists)):
    a = list(album_dict[unique_artists[i]])
    # print a
    if len(a) >= 1:
        if len(str(a[0])) == 1:
            # concatenate album
            # album_dict[unique_artists[i]] = ''.join(a)
            numAlbums = 1
        else:
            numAlbums = len(a)
        # will only record number of albums if it's greater than 1
        album_artist_counts[unique_artists[i]] = numAlbums
    else:
        album_artist_counts[unique_artists[i]] = 0

# %%
unique_artists
# Out:
# ['006',
#  '10,000 Maniacs',
#  '13Th Floor Elevators',
#  '13th Floor Elevators',
#  '16 Bit Lolitas',
#  '1954 Off-Broadway Revival Cast',
#  '2 Pac',
#  '20Th Century Zoo',
#  '2562',
#  '4hero',
#  '50 Cent',
#  '8-Bits & Q-Project',
#  '80kidz',
#  '? and the Mysterians',
#  'A Band of Bees (The Bees)',
#  'A Made Up Sound',
#  'A Sides',
#  'A Skillz / Lords Of The Underground',
#  'A Tribe Called Quest',
#  'A-Sides',
#  'A-Trak',
#  'A.F.I.',
#  'AC Slater',
#  'AFGHANISTAN',
#  'AFX',
#  'AP-9',
#  'ARN:MIKL',
#  'ASC',
#  'AUN',
#  'Aaliyah',
#  'Aaron Cometbus',
#  'Aaron Copland',
#  'Aaron Copland & London Symphony Orchestra',
#  'Abdullah Ibrahim',
#  'Abstract Elements',
#  'Acafool',
#  'Ace',
#  'Ace Creator',
#  'Act 1',
#  'Action Beat',
#  'Active Child',
#  'Active Minds',
#  'Actress',
#  'Adam & The Ants',
#  'Adam F',
#  'Adam Freeland and The Soul Drummers',
#  'Addison Groove',
#  'Adele',
#  'Adonis',
#  'Adrian Boult: New Philharmonia Orchestra',
#  'Adrien Kessler',
#  'Aeroplane',
#  'Aesop Rock',
#  'African Head Charge',
#  'Agents Del Futuro',
#  'Aim',
#  'Aimee Mann',
#  'Air',
#  'Air France',
#  'Akron/Family',
#  'Al Di Meola, John McLauglin, Paco De Lucia',
#  'Al Green',
#  'Al Hibbler',
#  'Al Vibrators / Ossie Count And His Band',
#  'Alabama Sacred Harp Singers',
#  'Alan Braxe',
#  'Alan Braxe & Fred Falke',
#  'Alan Hovhaness',
#  'Alan Reeves/Phil Steele/Philip Brigham',
#  'Alanis Morisette',
#  'Alanis Morissette',
#  'Alarm Will Sound',
#  'Alaska In Winter',
#  'Alban Berg',
#  'Albert King',
#  'Alberta Adams',
#  'Albino Allstars',
#  'Alborosie',
#  'Alela Diane',
#  "Alessi'S Ark",
#  'Alessio Mereu & Matteo Spedicati',
#  'Alex Cortex',
#  'Alex Gopher',
#  'Alex Mills',
#  'Alex Smoke',
#  'Alexis Stevens',
#  'Alexis Weissenberg',
#  'Ali B',
#  'Alice Cooper',
#  'Alice In Chains',
#  'Alison David',
#  'Alix Perez',
#  'Alix Perez & Lynx',
#  'Alix Perez & Sabre',
#  'All Thieves',
#  'Allen Toussaint',
#  'Aloe Blacc',
#  'Alter Ego',
#  'Altitude',
#  'Alvin Lucier',
#  'Amaning vs. Dubwise',
#  'Amerie',
#  'Ammoncontact',
#  'Amon Tobin',
#  'Amon Tobin - Bricolage - 12',
#  'Amorphous Androgynous',
#  'Amos Milburn',
#  'Amy Winehouse',
#  'Amy Winehouse Feat. Ghostface Killah',
#  'Analog Fingerprints',
#  'Ananda Shankar',
#  'Andre 3000',
#  'Andre Nickatina',
#  'Andre Nickatina And Mac Dre',
#  'Andrew & Jim Baxter',
#  'Andrew Bird',
#  'Andrew Tibbs',
#  'Andr\xc3\xa9 Previn: Royal Philharmonic Orchestra',
#  'Andy Capp',
#  'Angelo Badalamenti',
#  'Angus Carlyle & Rupert Cox',
#  'Anika',
#  'Animal Collective',
#  'Animated',
#  'Ann Peebles',
#  'Anne James Chaton & Andy Moor',
#  'Anne Peebles',
#  'Annie',
#  'Annu Malik Feat. Asha Bhosie And Chorus',
#  'Anthology of American Folk Music, Vol. 2 A',
#  "Anthony 'Sangie' Davis & Lee Perry",
#  'Anthony Shakir',
#  'Anton Dermota & The Austrian State Radio Orchestra',
#  'Anton Ellis',
#  'Anton Webern',
#  'Antonio Carlos Jobim',
#  'Antony & the Johnsons',
#  'Apathy',
#  'Aphex Twin',
#  'Apollon / Muslimgauze',
#  'Apple',
#  'Appleblim',
#  'Aquasky',
#  'Araabmuzik',
#  'Arabian Prince',
#  'Arbee Stidham',
#  'Archie Bell And The Drells',
#  'Aretha Franklin',
#  'Argy & The Martinez Brothers',
#  'Armand van Helden',
#  'Armando Gallop & Steve Poindexter',
#  'Arnold Schoenberg',
#  'Arnold Sch\xc3\xb6nberg',
#  'Arnold, Billy Boy',
#  'Arpadys',
#  'Art Blakey',
#  'Art Blakey & The Jazz Messengers',
#  'Artbox',
#  'Arthur "Big Boy" Crudup',
#  'Arthur Alexander',
#  'Arthur Conley',
#  'Arthur Crudup',
#  'Arthur Gunter',
#  'Arthur Kreiger',
#  'Artifact Shore',
#  'Artifical Intelligence & Krust',
#  'Artificial Intelligence',
#  'Arto Lindsay & Melvin Gibbs Vs. Taraf De Ha\xc3\xafdouks',
#  'Artwork',
#  'Arvo P\xc3\xa4rt',
#  'Asha Bhosle',
#  'Asha Bhosle & Chorus',
#  'Asha Bhosle & Mohammed Rafi',
#  'Asian Dub Foundation',
#  'Aspec(t)',
#  'Aspects',
#  'Aston "family Man" Barrett',
#  'Astrud Gilberto',
#  'Aswad - Rebel Souls',
#  'At The Drive In',
#  'Ation',
#  'Atomic Hooligan',
#  'Atomic Rooster',
#  'Audio Bullys',
#  'Audio Soul Project',
#  'Audion',
#  'Audrey Bryant',
#  'Augustus Pablo',
#  "Augustus Pablo Meets King Tubby's",
#  'Autechre',
#  'Autoerotique',
#  'Avatar Escape',
#  'Avey Tare & Kria Brekkan',
#  'Axel Boman',
#  'B-Movie',
#  'B. Dylan',
#  'B. Robindore',
#  'B.B. King',
#  'B.B.Seaton',
#  'B.W.H.',
#  'BK Cyph',
#  'BLUE JAM',
#  'BT',
#  'Baaba Maal',
#  'Baby Cham',
#  'Baby Face Leroy',
#  'Baby Oliver',
#  'Babylon Wrong',
#  'Babytalk',
#  'Backdraft',
#  'Backyard Dog',
#  'Bad Brains',
#  'Bad Company UK',
#  'Bad Livers',
#  'Badfinger',
#  'Badmarsh & Shri',
#  'Bahirij',
#  'Balanescu Quartet',
#  'Banco De Gaia',
#  'Band Of Skulls',
#  'Bangers and Cash',
#  'Bango Collective',
#  'Baobinga',
#  'Baobinga & I.D.',
#  'Barbara & the Browns',
#  'Barbara Lewis',
#  'Barbara Stephens',
#  'Baron',
#  'Baron Zen',
#  'Barrington Levy',
#  'Barry Adamson',
#  'Bascom Lamar Lunsford',
#  'Basement Jaxx',
#  'Basher feat. Xtrah',
#  'Basic Physics',
#  'Bassbin Twins',
#  'Bassnectar',
#  'Bastro',
#  'Batida',
#  'Battles',
#  'Bauhaus',
#  'Be Bop Deluxe',
#  'Beach House',
#  'Bearded Lady',
#  'Beastie Boys',
#  'Beat Conductor',
#  'Beat Konducta',
#  'Beatnuts',
#  'Bebel Gilberto',
#  'Beck',
#  'Bee Gees',
#  'Beenie Man',
#  'Beginning Of The End',
#  'Beirut',
#  'Bela Bartok',
#  'Bell Biv DeVoe',
#  'Belle & Sebastian',
#  'Ben E. King',
#  'Ben Folds Five',
#  'Ben Frost',
#  'Ben Johnston',
#  'Benga',
#  'Benga & Coki',
#  'Benga & Skream',
#  'Benjamin Britten',
#  "Benjamin Britten, Boys' Choir Emanuel School Wandsworth, Downside School, Purley, Choir Of & London Symphony Orchestra",
#  'Benjamin Francis Leftwich',
#  'Benny Benassi',
#  'Benny Benassi Feat. Channing',
#  'Benny Benassi Feat. Christian Burns',
#  'Benny Benassi Feat. Dino',
#  'Benny Benassi Feat. Farenheit',
#  'Benny Benassi Feat. Mia J',
#  'Benny Benassi Feat. Naan',
#  'Benny Benassi Vs. Iggy Pop',
#  'Benny Benassi Vs. Public Enemy',
#  'Benny Spellman',
#  'Bent',
#  'Beres Hammond',
#  'Berou & Canblaster',
#  'Bert Jansch',
#  'Bert Jansch and John Renbourn',
#  'Bessie Smith',
#  'Best Fwends',
#  'Beth Orton',
#  'Bette Midler',
#  'Better Than Ezra',
#  'Betty Davis',
#  'Betty Wright',
#  'Beyonce',
#  'Bibio',
#  'Bicep',
#  'Biddu',
#  'Biddu Feat. Manhar And Anand',
#  'Big Al Sears',
#  'Big Beats',
#  'Big Bill Broonzy',
#  'Big Bird',
#  'Big Boi',
#  'Big Boi feat. Bun B And Big Gee',
#  'Big Boi feat. Killer Mike',
#  'Big Brother & Holding Company Featuring Janis Joplin',
#  'Big Brother & The Holding Company',
#  'Big Hair & Earl Gateshead',
#  'Big Joe',
#  'Big Joe Turner',
#  'Big Joe Williams',
#  'Big L',
#  'Big Mama Thornton',
#  'Big Star',
#  'Big Three Trio',
#  'Big Tymers',
#  'Big Tymers (DJ Screw)',
#  'Big Youth',
#  'Bigga Bush Vs Ko\xc3\xa7ani Orkestar',
#  'Bill & Belle Reed',
#  'Bill Callahan',
#  'Bill Evans',
#  'Bill Frisell',
#  'Bill Haley & His Comets',
#  'Bill Haley and The Comets',
#  'Bill Withers',
#  'Billie Holiday',
#  'Billions and Billions',
#  'Billy & The King Bees',
#  'Billy Bragg',
#  'Billy Idol',
#  'Billy Joel',
#  'Billy Mann',
#  'Billy Ocean',
#  'Billy Squier',
#  'Bishop Perry Tills',
#  'Bitty McLean',
#  'Bj\xc3\xb6rk',
#  'Black Box Vs. Benny Benassi',
#  'Black Flag',
#  'Black Lips',
#  'Black Lodge',
#  'Black Mafia',
#  'Black Moth Super Rainbow',
#  'Black Rebel Motorcycle Club',
#  'Black Sabbath',
#  'Black Slate',
#  'Black Star Liner',
#  'Black Sugar',
#  'Black Uhuru',
#  'Black Widow',
#  'Blackbelt Andersen',
#  'Blackbird Blackbird',
#  'Blackdown',
#  'Blackfinger vs Benga & Coki',
#  'Blackstar/Mos Def/Talib Kweli',
#  'Blame',
#  'Blank Disco',
#  'Blawan',
#  'Blind Boy Fuller',
#  'Blind Faith',
#  'Blind Lemon Jefferson',
#  'Blind Melon',
#  'Blind Willie Johnson',
#  'Blind Willie McTell',
#  'Bloc Party',
#  'Blondie',
#  'Blood, Sweat, & Tears',
#  'Blossom Toes',
#  'Blue',
#  'Blue Cheer',
#  'Blue Ketchuppp',
#  'Blue Magic',
#  'Blue Period',
#  'Blue Roses',
#  'Blue Velvet',
#  'Blues Image',
#  'Blues Magoos',
#  'Blues Traveler',
#  'Blufoot',
#  'Blur',
#  'Bo Diddley',
#  'Boards Of Canada',
#  'Bob Andy',
#  'Bob B. Soxx & the Blue Jeans',
#  'Bob Becker, Jay Clayton, Mort Silver, Pamela Wood Ambush & Steve Reich',
#  'Bob Bellerue',
#  'Bob Dylan',
#  'Bob Dylan & The Rolling Thunder Review',
#  'Bob Dylan And Johnny Cash',
#  'Bob Dylan and the Band',
#  'Bob Marley',
#  'Bob Marley & The Wailers',
#  'Bob Wills',
#  'Bobby "Blue" Bland',
#  'Bobby Bland',
#  'Bobby Charles',
#  'Bobby Charles And The Generations',
#  'Bobby Darin',
#  'Bobby Hebb',
#  'Bobby Marchan',
#  'Bobby Mitchell',
#  'Bobby Peru',
#  'Bobby Roberts & The Rave Ons',
#  'Bobby Taylor & The Vancouvers',
#  'Bobby Vee',
#  'Bobby Wilson',
#  'Bobby Womack',
#  'Bobmo',
#  'Boddika & Joy Orbison',
#  'BodyRockers',
#  'Bodycode',
#  'Bohm & Cooper-Marquardt Duo',
#  'Bombay Squad',
#  'Bombay the hard way',
#  'Bombing F',
#  'Bonafide',
#  'Bonde Do Role',
#  'Bonde do Rol\xc3\xaa',
#  'Bone Thugs-N-Harmony',
#  'Bone Thugs-N-Harmony Feat. 3LW & Felecia',
#  'Bone Thugs-N-Harmony Feat. Avant',
#  'Bone Thugs-N-Harmony Feat. Big Chan',
#  'Bone Thugs-N-Harmony Feat. Phil Collins',
#  'Bong-Ra',
#  'Bongo Herman',
#  'Bongo Herman / Chen, Les',
#  'Bongo Herman / Eric "Bingy Bunny" Lamont',
#  'Bongo Herman / Harry J All Stars',
#  'Bonnie Raitt',
#  'Bonobo Feat. Andreya Triana',
#  'Boogie Down Productions',
#  'Booka Shade',
#  "Booker T. & The MG's",
#  "Booker T. & the MG's",
#  'Boom Bip, Doseone, & Clouddead',
#  'Boom Jinx & Andrew Bayer',
#  'Bootsy Collins',
#  'Boredoms',
#  'Boston',
#  'Boston Jack / Soulites',
#  'Bounty Killer',
#  'Boy Blues',
#  'Boy Friday',
#  'Boy Hits Car',
#  'Boyd Eddie',
#  'Boys Noize',
#  'Boyz II Men',
#  'Brad Paisley',
#  'Brand Nubian',
#  'Brazilian Girls',
#  'Break',
#  'Breakage',
#  "Breakage feat. Donae'o",
#  'Breakage feat. Newham Generals and David Rodigan',
#  'Breakbot',
#  'Breakestra',
#  'Breaux Freres',
#  'Breeders',
#  'Brian Eno',
#  'Brian Eno And David Byrne',
#  'Brian Eno And The Words Of Rick Holland',
#  'Brian Wilson',
#  'Brick',
#  'British Lions',
#  'Britney Spears',
#  'Britney Spears - HHG',
#  'Broadcast',
#  'Brockie & Ed Solo',
#  'Brodinski & Tony Senghore',
#  'Broken Records',
#  'Broken Social Scene',
#  'Brook Benton',
#  'Brothers & Sisters',
#  'Bruce Hornsby & The Range',
#  'Bruce Springsteen',
#  'Bruno Walter, Kathleen Ferrier & Wiener Philharmoniker',
#  'Bubba Sparxxx',
#  'Bubba Sparxxx feat. Killer Mike',
#  'Buck Owens',
#  'Buckfunk 3000',
#  'Bucovina Club Vs Taraf De Ha\xc3\xafdouks',
#  'Buddy Guy',
#  'Buddy Holly',
#  'Buddy Holly & The Crickets',
#  'Buell Kazee',
#  'Buena Vista Social Club',
#  'Buffalo Springfield',
#  'Bugz in the Attic',
#  'Built To Spill',
#  'Bukka White',
#  'Bumcello Vs Taraf De Ha\xc3\xafdouks',
#  'Bunny & Ricky',
#  'Bunny Wailer',
#  'Buraka Som Sistema',
#  'Burial',
#  'Burning Sensations',
#  'Burning Spear',
#  'Burro Banton',
#  'Busdriver',
#  'Busdriver Feat. Bianca Casady',
#  'Bushwacka!',
#  'Busta Rhymes',
#  'Buster Carter & Preston Young',
#  'Busy P',
#  'Butch',
#  'Butthole Surfers',
#  'Byron Lee',
#  'Byron Lee & The Dragonaires',
#  'C',
#  'C.L. Blast',
#  'C83',
#  'CAN',
#  'CARDINALS',
#  'CHC',
#  'CLS',
#  'CX Kidtronik feat. Rockola',
#  'Cadence Weapon',
#  'Cadenza',
#  'Caetano Veloso',
#  'Cajmere',
#  'Calenda',
#  'Calibre',
#  'Calvin Harris',
#  'Calyx',
#  'Camel',
#  'Cameo',
#  'Camper Van Beethoven',
#  'Can',
#  'Canes',
#  'Canned Heat',
#  'Cannibal & The Headhunters',
#  "Cannon's Jug Stompers",
#  "Cannon's Jug Stopers",
#  'Cannonball Adderley',
#  'Cansei de Ser Sexy',
#  'Caper',
#  'Capleton',
#  'Cappo',
#  'Captain Beefheart',
#  'Captain Beefheart & His Magic Band',
#  'Captain Beefheart & The Magic Band',
#  'Captain Beyond',
#  'Cardinals',
#  'Caretakers OF Deception',
#  'Carey & Lurrie Bell',
#  'Caribou',
#  'Carl Murphy',
#  'Carl Orff',
#  'Carla Thomas',
#  'Carla Thomas/Otis Redding',
#  'Carla Thomas/Rufus Thomas',
#  'Carlton Jackson',
#  'Carol Burnett',
#  'Carole King',
#  'Carolina Tar Heels',
#  'Carreras, Domingo, Pavarotti',
#  'Carter Burwell',
#  'Casey Veggies',
#  'Casey Veggies Feat. Ace Creator',
#  'Casey Veggies Feat. Tyler Creator',
#  'Casino ambients',
#  'Caspa',
#  'Caspa & Rusko',
#  'Caspa & The Others',
#  'Cassius',
#  'Cat Power',
#  'Cat Stevens',
#  'Catherine Christer Hennix',
#  'Cave',
#  'Cave In',
#  'Ceasefire vs. Deadly Avenger',
#  'Cecil Grant',
#  'Cecil Taylor',
#  'Cee-Lo/Danger Doom',
#  'Chad Jackson',
#  'Cham',
#  'Chamillionaire',
#  'Chamillionaire; Paul Wall',
#  'Charlemagne',
#  'Charles Ives',
#  'Charles Manson',
#  'Charles Mingus',
#  'Charles Mingus Sextet/Eric Dolphy',
#  'Charles Tr\xc3\xa9net',
#  'Charles Wright & The Watts 103rd Street Rhythm Band',
#  'Charlie Dore',
#  'Charlie Feathers',
#  'Charlie Parker',
#  'Charlie Poole With The North Carolina Ramblers',
#  'Chase & Status',
#  'Chasing Shadows',
#  'Cheap Trick',
#  'Chemical Submission Mix',
#  'Cherish',
#  'Cherub',
#  'Cheryl Johnson/Pam Johnson',
#  'Cheryl Lynn',
#  'Chexlia Chan',
#  'Chezidek',
#  'Chic',
#  'Chicago',
#  'Chicken Lips',
#  'Chicks on Speed',
#  'Childish Gambino',
#  'Children Of The Night',
#  'Chilly Gonzales',
#  'Chingon',
#  "Chris 'The Glove' Taylor & David Storrs",
#  'Chris Clark',
#  'Chris Farlowe',
#  'Chris Kenner',
#  'Chris.Su & SKC',
#  'Christian Fischer vs. Hybrid',
#  'Christian Skj\xc3\xb8dt',
#  'Christian Smith & John Selway',
#  'Christina Aguilera',
#  'Christine Kittrell',
#  'Chromeo',
#  'Chubby Parker',
#  'Chubby Parker & His Old Time Banjo',
#  'Chuck Berry',
#  'Chuck Fenda',
#  'Chuck Fender',
#  'Chuck Willis',
#  'Ciara',
#  'Ciara feat. Ludacris',
#  'Ciccone Youth',
#  'Cincinnati Jug Band',
#  'Circle Jerks',
#  'Circuit Breaker',
#  'Cirith Ungol',
#  'Citizen Cope',
#  'City of Women',
#  'Clancy Eccles',
#  'Clarence "Tom" Ashley',
#  'Clarence Ashley',
#  'Clarence Carter',
#  'Clarence Samuels',
#  'Clark',
#  'Claude Debussy',
#  'Claude VonStroke',
#  'Clefs of Lavender Hill',
#  'Clement Meyer',
#  'Cleo Laine',
#  'Cleoma Breaux And Joseph Falcon',
#  'Clifford Brown & Max Roach',
#  'Clifford Curry',
#  'Clinic',
#  'Clint Eastwood',
#  'Clint Mansell',
#  'Clipse',
#  'Clipz',
#  'Club Nouveau',
#  'Cluster',
#  'Cluster & Eno',
#  'Clyde McPhatter',
#  'Clyde McPhatter And The Drifters',
#  'Coachwhips',
#  'Cobras',
#  'CocoRosie',
#  'Cocteau Twins',
#  'Code 3',
#  'Coil',
#  'Coki',
#  'Cold War Kids',
#  'Coldcut',
#  'Coldplay',
#  'Coley Jones',
#  'Collective Soul',
#  'Collie Buddz',
#  'Columbia Symphony Orchestra & Igor Fyodorovitch Stravinsky',
#  'Columbus Fruge',
#  'Commix',
#  'Common',
#  'Common Feat. Bilal',
#  'Common Feat. Bilal & John Legend',
#  'Common Feat. John Mayer',
#  'Common Feat. Kanye West & John Legend',
#  'Common Feat. The Last Poets',
#  'Compound One',
#  'Comus',
#  'ConQuest',
#  'Conjure',
#  'Conquest',
#  'Consequence',
#  'Contemporary Noise Sextet',
#  'Coolio',
#  'Cop & Thief VS Taraf De Ha\xc3\xafdouks',
#  'Cornelius',
#  'Cornell Campbell',
#  'Cornershop',
#  'Cosmin TRG',
#  'Cotti & ClueKid',
#  'Count Basie',
#  'Count Five',
#  'Count Ossie & Mystic Revelation Of Rastafari',
#  'Count Ossie / Leslie Butler',
#  'Count Ossie / Mystic Revelation',
#  'Count Prince Miller',
#  'Counting Crows',
#  'Country Joe & The Fish',
#  'Country Joe and the Fish',
#  'Craggz & Parallel Forces',
#  'Craig Armstrong',
#  'Crayzee Bandit',
#  'Crazy Bald Heads',
#  'Crazy Penis',
#  'Cream',
#  'Creedence Clearwater Revival',
#  'Crime Mob',
#  'Crime Scene (Thizz Rock)',
#  'Crippled Black Phoenix',
#  'Critical Impact & Komonazmuk',
#  'Crooked Fingers',
#  'Crooked I',
#  'Crooklyn Clan',
#  'Cropper/Jackson/Jones/Lewis Steinberg',
#  'Crosby, Stills & Nash',
#  'Crosby, Stills, Nash & Young',
#  'Crowded House',
#  'Crystal Castles',
#  'Cuby & The Blizzards',
#  'Culture',
#  'Culture Shock',
#  'CunningLynguists',
#  'Curtis Lee',
#  'Curtis Mayfield',
#  'Curtis Roads',
#  'Cut Chemist & This Kid Named Miles',
#  'Cut Copy',
#  'Cutty Ranks',
#  'Cyantific',
#  'Cyantific & Logistics',
#  'Cybotron',
#  'Cyndi Lauper',
#  'D-Bridge',
#  'D-Nice',
#  'D1',
#  'D12',
#  'D12 Feat. B-Real',
#  'D12 Feat. Obie Trice',
#  'DEATH',
#  'DJ AP',
#  'DJ Abstract',
#  'DJ Assault',
#  'DJ Balli',
#  'DJ Blaqstarr',
#  'DJ CROWD & LIL WAYNE THE DROUGHT IS OVER 5',
#  'DJ Class',
#  'DJ Craze',
#  'DJ Dee Kline & Ed Solo',
#  'DJ Deeon',
#  'DJ Die & Interface',
#  'DJ Dolores Vs Taraf De Ha\xc3\xafdouks',
#  'DJ Format',
#  'DJ Fresh feat. Stamina MC and Koko',
#  'DJ Funk',
#  'DJ G',
#  'DJ Gant-Man',
#  'DJ Hazard',
#  'DJ Hype',
#  'DJ Icey',
#  'DJ Khaled',
#  'DJ Khaled & Drake',
#  'DJ Krave',
#  'DJ LBR',
#  'DJ Laz',
#  'DJ Llopis',
#  'DJ Love',
#  'DJ Magic Mike',
#  'DJ Malvado',
#  'DJ Marky & S.P.Y.',
#  'DJ Marky & XRS',
#  'DJ Marky, Bungle & DJ Roots',
#  'DJ Mp4',
#  'DJ Mujava',
#  'DJ Nasty',
#  'DJ Oddz',
#  'DJ Phantasy',
#  'DJ Q-Bert',
#  'DJ Riot',
#  'DJ Screw',
#  'DJ Shadow',
#  'DJ Shadow & Radiohead',
#  'DJ Shadow Feat. Chris James',
#  'DJ Shadow Feat. Christina Carter',
#  'DJ Shadow Feat. David Banner',
#  'DJ Shadow Feat. E-40',
#  'DJ Shadow Feat. Keak Da Sneak & Turf Talk',
#  'DJ Shadow Feat. Mistah Fab, Turf Talk & Keak Da Sneak',
#  'DJ Shadow Feat. Nump',
#  'DJ Shadow Feat. Phonte Coleman',
#  'DJ Shadow Feat. Q-Tip & Lateef The Truth Speaker',
#  'DJ Shadow Feat. The Federation & Animaniaks',
#  'DJ Soul Slinger',
#  'DJ Spice',
#  'DJ Spooky',
#  'DJ Technique',
#  'DJ Who',
#  'DJ Yoda',
#  'DJ Zinc',
#  'DJ Znobia',
#  'DJs From Mars',
#  'DKD',
#  'DKay.com',
#  'DM Stith',
#  'DMX',
#  'DPM',
#  'DQ 1',
#  'Dadawah',
#  'Daddy Freddy',
#  'Daddy Freddy Meets Rootsman',
#  'Daft Punk',
#  'Dalglish',
#  'Daluq',
#  'Dam-Funk',
#  "Damian 'Jr. Gong' Marley",
#  'Dan Auerbach',
#  'Dan Deacon',
#  'Dan HabarNam',
#  'Dan the Automator',
#  'Dance Area',
#  'Dance Disaster Movement',
#  'Dandy & Down To Earth',
#  'Dandy Livingstone',
#  'Danger Doom',
#  'Danger Doom/Ghostface',
#  'Danger Doom/Talib Kweli',
#  'Danger Mouse',
#  'Danger Mouse & Jemini',
#  'Dangermouse',
#  'Daniel Diamond',
#  'Daniel Johnston',
#  'Daniel Portman',
#  'Daniel Teruggi',
#  'Daniel Wang',
#  "Daniel's In The Lion's Den & Carl Douglas",
#  'Daniele Papini',
#  'Danny & The Otherguys',
#  'Danny & The Royal Strings',
#  'Danny Byrd',
#  'Danny C',
#  "Dantalion's Chariot",
#  'Dao',
#  'Daria Semegen',
#  'Darius Milhaud',
#  'Darlene Love',
#  'Darqwan',
#  'Darth & Vader',
#  'Data',
#  'Dataworx',
#  'Dave Barker',
#  'Dave Brubeck Quartet',
#  'Dave Horne',
#  'Dave Spoon',
#  'David Borden',
#  'David Bowie',
#  'David Byrne',
#  'David Byrne and Brian Eno',
#  'David Byrne/Caetano Veloso',
#  'David Crosby',
#  'David Garza',
#  'David Grisman, Jerry Garcia',
#  'David Holmes',
#  'David Isaacs',
#  'David Porter',
#  'David Shire',
#  'Davie Allan & the Arrows',
#  'Davina',
#  'Davy Jones',
#  'De La Soul',
#  'Dead Kennedys',
#  'Dead Moon',
#  'Dead Prez',
#  'Dead kennedys',
#  'Deadly Avenger',
#  'Deadly Habit',
#  'Deadmau5',
#  'Dean Martin',
#  'Deana Carter',
#  'Deanie Parker',
#  'Deanie Parker/Valadors',
#  'Death From Above 1979',
#  'Death in Vegas',
#  'Debbie Deb',
#  'Debussy',
#  'Debussy ',
#  'Deep Blue Something',
#  'Deep Purple',
#  'Deerhoof',
#  'Deerhunter',
#  'Deftones',
#  'Del Rays',
#  'Del Shannon',
#  'Del Tha Funky Homosapien',
#  'Deleted Scenes',
#  'Delinquents, Keak Da Sneak, Ba',
#  'Delma Lachney And Blind Uncle Gaspard',
#  'Delroy Wilson',
#  'Deltron',
#  'Demon Boyz',
#  'Dennis Brown',
#  'Dennis Walks & The Pioneers',
#  'Dennis Wilson',
#  'Depeche Mode',
#  'Derek Martin',
#  'Derek and the Dominos',
#  'Derrick Morgan',
#  'Desaparecidos',
#  'Descendents',
#  'Desmond Dekker',
#  'Desmond Dekker & The Aces',
#  'Destroyer',
#  'Detroit Jr.',
#  'Devendra Banhart',
#  'Devin The Dude',
#  'Devo',
#  'Diagonal',
#  'Dice And Cummie',
#  'Dick Dale',
#  'Dick Justice',
#  'Didier H\xc3\xa9bert',
#  'Die & Skitz',
#  'Die Barbie Musik Kollektiv',
#  'Dietrich Fischer-Dieskau, baritone; The Juiilliard Quartet',
#  'Digable Planets',
#  'Digital',
#  'Digital Mystikz',
#  'Digital Mystikz feat. Spen G',
#  'Dilated Peoples',
#  'Dillinger',
#  'Dillinja',
#  'Dillon Francis & Diplo',
#  'Dimitris Bakas',
#  'Dinah Washington',
#  'Dinky',
#  'Dion & The Belmonts',
#  'Diplo',
#  'Diplo & Laidback Luke',
#  'Dire Straits',
#  'Discodeine',
#  'Dishwalla',
#  'Distal',
#  'Distance',
#  'Divine Styler',
#  'Divit',
#  'Dizzee Rascal',
#  'Dizzee Rascal and Armand Van Helden',
#  'Dj Mehdi',
#  'Django Reinhardt',
#  'Djedjotronic',
#  'Djuma Soundsystem',
#  'Dmitri Shostakovich',
#  'Dock Boggs',
#  'Doctor P',
#  'Doctor Rockit',
#  'Dominatrix',
#  'Domino Johnson',
#  'Don Carlos',
#  'Don Cherry',
#  'Don Covay',
#  'Donald Byrd & 125th Street, N.Y.C.',
#  'Donna Summer',
#  'Donny Hathaway',
#  'Donny Ray & The Falcons',
#  'Donovan',
#  'Dope Smugglaz',
#  'Doris Troy',
#  'Dorothy Williams',
#  'Doug Paisley',
#  'Doug Willis',
#  'Downer, Prince Roland / Ossie, Count And His Band',
#  'Dr Israel',
#  'Dr. Dog',
#  'Dr. Dre',
#  'Dr. Dre Feat RBX And Snoop Dogg',
#  'Dr. Dre Feat. D.O.C And Snoop Dogg',
#  'Dr. Dre Feat. Kurupt, RBX, Rage, Snoop Dogg, And D.O.C',
#  'Dr. Dre Feat. Mary J. Blige',
#  'Dr. Dre Feat. Snoop Dogg',
#  'Dr. Dre Feat. That Nigga Daz, Snoop Dogg, Colin Wolfe And Nate Dogg',
#  'Dr. Dre feat. Kevin Lewis, Jewell, and Rage',
#  'Dr. Dre feat. Kurupt, RBX and Snoop Dogg',
#  'Dr. Dre feat. RBX and Colin Wolfe',
#  'Dr. Dre feat. RBX, Snoop Dogg and That Nigga Daz',
#  'Dr. Dre feat. Snoop Dogg and D.O.C',
#  'Dr. Dre feat. Snoop Dogg, Colin Wolfe',
#  'Dr. Evil',
#  'Dr. Feelgood',
#  'Dr. Isaiah Ross',
#  'Dr. John',
#  'Dr. Zeus Vs DJ Sanj',
#  'Dramatic & DBAudio',
#  'Dre Skull',
#  'Dread in Babylon',
#  'Dreadzone',
#  'Dream Syndicate',
#  'Drift',
#  'Drist',
#  'Drop the Lime',
#  'Drums of Death',
#  'Drumsound and Bassline Smith',
#  'Dryspell',
#  ...]

# %%
ar_sorted2[110].name
# Out:
# 'A Tribe Called Quest'
